# %%
import pandas as pd
import matplotlib.pyplot as plt


data = pd.read_csv("C:\\Users\\khyat\\Downloads\\IRIS.csv")

# %%
plt.hist(data['sepal_length'], bins=10, color='skyblue')

plt.xlabel('sepal_length')
plt.ylabel('Frequency')
plt.title('Histogram of Age')

plt.show()
